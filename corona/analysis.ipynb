# %%
import pandas as pd

# %%
data = pd.read_csv("complete.csv")

# %%
data.head()
# Out:
#             Name of State / UT  Total Confirmed cases  \
# 0  Andaman and Nicobar Islands                     33
# 1                      Tripura                    118
# 2                    Telengana                   1133
# 3                   Tamil Nadu                   6009
# 4                    Rajasthan                   3579
#
#    Cured/Discharged/Migrated  \
# 0                         33
# 1                          2
# 2                        700
# 3                       1605
# 4                       1916
#
#    Deaths ( more than 70% cases due to comorbidities )        Date  Latitude  \
# 0                                                  0    2020-05-09   11.7401
# 1                                                  0    2020-05-09   23.9408
# 2                                                 29    2020-05-09   18.1124
# 3                                                 40    2020-05-09   11.1271
# ...

# %%
data.columns
# Out:
# Index(['Name of State / UT', 'Total Confirmed cases',
#        'Cured/Discharged/Migrated',
#        'Deaths ( more than 70% cases due to comorbidities )', 'Date',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
a=data['Date'].dt.year

# %%
b=data['Date'].dt.month

# %%
c=data['Date'].dt.day

# %%
data['day'] = c
data['month'] = b

# %%
data.head()
# Out:
#             Name of State / UT  Total Confirmed cases  \
# 0  Andaman and Nicobar Islands                     33
# 1                      Tripura                    118
# 2                    Telengana                   1133
# 3                   Tamil Nadu                   6009
# 4                    Rajasthan                   3579
#
#    Cured/Discharged/Migrated  \
# 0                         33
# 1                          2
# 2                        700
# 3                       1605
# 4                       1916
#
#    Deaths ( more than 70% cases due to comorbidities )       Date  Latitude  \
# 0                                                  0   2020-05-09   11.7401
# 1                                                  0   2020-05-09   23.9408
# 2                                                 29   2020-05-09   18.1124
# 3                                                 40   2020-05-09   11.1271
# ...

# %%
data.rename(columns = {'Deaths ( more than 70% cases due to comorbidities )' : 'Deaths'},inplace = True)

# %%
data.head()
# Out:
#             Name of State / UT  Total Confirmed cases  \
# 0  Andaman and Nicobar Islands                     33
# 1                      Tripura                    118
# 2                    Telengana                   1133
# 3                   Tamil Nadu                   6009
# 4                    Rajasthan                   3579
#
#    Cured/Discharged/Migrated  Deaths       Date  Latitude  Longitude  day  \
# 0                         33       0 2020-05-09   11.7401    92.6586    9
# 1                          2       0 2020-05-09   23.9408    91.9882    9
# 2                        700      29 2020-05-09   18.1124    79.0193    9
# 3                       1605      40 2020-05-09   11.1271    78.6569    9
# 4                       1916     101 2020-05-09   27.0238    74.2179    9
#
#    month
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
